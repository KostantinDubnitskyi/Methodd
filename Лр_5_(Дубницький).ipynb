# %% [markdown]
# <a href="https://colab.research.google.com/github/KostantinDubnitskyi/Methodd/blob/main/%D0%9B%D1%80_5_(%D0%94%D1%83%D0%B1%D0%BD%D0%B8%D1%86%D1%8C%D0%BA%D0%B8%D0%B9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Лабораторна робота 5
#
# Розв'язання систем нелінійних рівнянь.

# %%
#Розв'язання систем нелінійних рівнянь та графік
import numpy as np
import matplotlib.pyplot as plt

# Область значень для x та y
x_min, x_max = -3, 4
y_min, y_max = -3, 4
step = 0.01

# Створюємо масиви значень x та y
x, y = np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))

# Рівняння системи
eq1 = np.cos(x + 0.5) - 0.8
eq2 = np.sin(y) - 2 * x - 1.6

# Створюємо графік
fig, ax = plt.subplots(figsize=(10, 10))

# Додаємо графік першого рівняння
ax.contour(x, y, eq1, levels=[0], colors='red')

# Додаємо графік другого рівняння
ax.contour(x, y, eq2, levels=[0], colors='blue')

# Налаштування графіка
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Графік системи рівнянь')

# Додаємо стрілки на кінцях осей
ax.arrow(x_min, 0, x_max - x_min, 0, head_width=0.1, head_length=0.05, fc='black', ec='black')
ax.arrow(0, y_min, 0, y_max - y_min, head_width=0.1, head_length=0.2, fc='black', ec='black')

# Додаємо сітку
plt.grid(True)

# Показуємо графік
plt.show()

# %%
import numpy as np
from scipy import optimize
from scipy.misc import derivative
# Початкові наближення
x0 = -0.1
y0 = -0.1

def f1(y):
    return 0.8 - np.cos(y + 0.5)

def f2(x):
    return (np.sin(x) - 1.6) / 2

def iter(x, y, e):
    xn = x
    yn = y
    xn1 = f2(yn)
    yn1 = f1(xn)
    n = 1
    while (abs(xn1 - xn) >= e) or (abs(yn1 - yn) >= e):
        xn = xn1
        yn = yn1
        xn1 = f2(yn)
        yn1 = f1(xn)
        n += 1
    print('Simple iteration:')
    print(f'x = {xn1:.4f}, y = {yn1:.4f}')
    print('The amount of iteration =', n)

iter(x0, y0, 0.00001)

#Задаємо функцію для перевірки
def f3(x):
    return np.cos(x[0] + 0.5) + x[1] - 0.8, np.sin(x[1]) - 2*x[0] - 1.6

s = optimize.root(f3, [x0, y0], method='hybr')#Перевірка розв*язку

print('Chek', s.x)
# Out:
# Simple iteration:
# x = -0.8666, y = -0.1336
# The amount of iteration = 11
# Chek [-0.86658081 -0.13355833]
